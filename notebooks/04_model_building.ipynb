# %% [markdown]
# # Model Building Baseline
#
# Notebook ini membangun baseline Decision Tree dan Random Forest langsung dari output preprocessing Milestone 1 di `data/processed/uci/` dan `data/processed/secondary/`, tanpa preprocessing ulang dan tanpa melatih model pada test set.

# %%
from src.modeling import run_all_modeling

summary = run_all_modeling()
summary.keys()

# %%
import pandas as pd

metrics = pd.read_csv('reports/tables/modeling/baseline_metrics.csv')
structure = pd.read_csv('reports/tables/modeling/model_structure_summary.csv')
metrics, structure
