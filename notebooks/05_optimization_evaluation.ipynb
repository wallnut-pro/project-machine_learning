# %% [markdown]
# # Milestone 04 - Optimization and Evaluation
#
# Notebook ini merangkum hasil tuning dan evaluasi model berdasarkan artefak aktual yang dihasilkan oleh `src/run_optimization_evaluation.py`.

# %%
from pathlib import Path
import json
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
TABLES_DIR = PROJECT_ROOT / 'reports' / 'tables' / 'evaluation'
TABLES_DIR

# %%
final_model_comparison = pd.read_csv(TABLES_DIR / 'final_model_comparison.csv')
best_hyperparameters = pd.read_csv(TABLES_DIR / 'best_hyperparameters.csv')
confusion_values = pd.read_csv(TABLES_DIR / 'confusion_matrix_values.csv')

final_model_comparison

# %%
best_hyperparameters

# %%
confusion_values

# %%
summary = json.loads((TABLES_DIR / 'optimization_summary.json').read_text(encoding='utf-8'))
summary
